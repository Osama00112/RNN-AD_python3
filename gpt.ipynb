# %%
import pandas as pd
# Out:
# C:\Users\Osama Haque\AppData\Local\Temp\ipykernel_2756\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('data/TADPOLE_D1_D2.csv')

df.head()
# Out:
# C:\Users\Osama Haque\AppData\Local\Temp\ipykernel_2756\43594492.py:1: DtypeWarning: Columns (471,473,474,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506,507,508,509,510,511,512,513,514,515,516,517,518,519,520,521,522,523,524,525,526,527,528,529,530,531,532,533,534,535,536,537,538,539,540,541,542,543,544,545,546,547,548,549,550,551,552,553,554,555,556,557,558,559,560,561,562,563,569,570,572,573,574,575,576,577,578,579,580,581,582,583,584,585,586,587,588,589,590,591,592,593,594,595,596,597,599,601,606,607,608,609,610,611,612,613,614,615,616,617,618,619,620,621,624,625,626,627,628,629,630,631,632,633,634,636,637,638,639,640,641,642,643,644,645,646,647,648,649,650,651,652,653,654,655,656,657,658,659,660,661,663,664,665,666,667,668,669,670,671,672,673,674,675,676,677,678,679,680,681,682,683,684,685,686,687,688,689,690,691,692,693,694,695,696,697,698,699,700,701,702,703,704,705,706,707,708,709,710,711,712,713,714,715,716,717,718,719,720,721,722,723,724,725,726,727,728,729,730,731,732,733,734,735,736,737,738,739,745,746,748,749,750,751,752,753,754,755,756,757,758,759,760,761,762,763,764,765,766,767,770,771,776,777,778,779,780,781,782,783,784,785,786,787,788,789,790,791,794,795,797,798,799,800,801,802,803,804,806,807,808,809,810,811,812,813,814,815,816,817,818,819,820,821,822,823,824,825,826,827,828,829,830,831) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/TADPOLE_D1_D2.csv')
#    RID        PTID VISCODE  SITE  D1  D2 COLPROT ORIGPROT    EXAMDATE DX_bl  \
# 0    2  011_S_0002      bl    11   1   1   ADNI1    ADNI1  2005-09-08    CN
# 1    3  011_S_0003      bl    11   1   0   ADNI1    ADNI1  2005-09-12    AD
# 2    3  011_S_0003     m06    11   1   0   ADNI1    ADNI1  2006-03-13    AD
# 3    3  011_S_0003     m12    11   1   0   ADNI1    ADNI1  2006-09-12    AD
# 4    3  011_S_0003     m24    11   1   0   ADNI1    ADNI1  2007-09-12    AD
#
#    ...  PHASE_UPENNBIOMK9_04_19_17  BATCH_UPENNBIOMK9_04_19_17  \
# 0  ...
# 1  ...                       ADNI1                 UPENNBIOMK9
# 2  ...
# 3  ...                       ADNI1                 UPENNBIOMK9
# 4  ...
#
#   KIT_UPENNBIOMK9_04_19_17  STDS_UPENNBIOMK9_04_19_17  \
# 0
# 1            P06-MP02-MP01            P06-MP02-MP01/2
# 2
# 3            P06-MP02-MP01            P06-MP02-MP01/2
# 4
#
#   RUNDATE_UPENNBIOMK9_04_19_17 ABETA_UPENNBIOMK9_04_19_17  \
# 0
# 1                   2016-12-14                      741.5
# 2
# 3                   2016-12-14                      601.4
# 4
#
#   TAU_UPENNBIOMK9_04_19_17  PTAU_UPENNBIOMK9_04_19_17  \
# 0
# 1                    239.7                      22.83
# 2
# 3                    251.7                      24.18
# 4
#
#    COMMENT_UPENNBIOMK9_04_19_17  update_stamp_UPENNBIOMK9_04_19_17
# 0
# 1                           NaN              2017-04-20 14:39:54.0
# 2
# 3                           NaN              2017-04-20 14:39:54.0
# 4
#
# [5 rows x 1907 columns]

# %%
#check count of columns
print("Number of columns: ", len(df.columns))
# Out:
# Number of columns:  1907

# %%
df.columns
# Out:
# Index(['RID', 'PTID', 'VISCODE', 'SITE', 'D1', 'D2', 'COLPROT', 'ORIGPROT',
#        'EXAMDATE', 'DX_bl',
#        ...
#        'PHASE_UPENNBIOMK9_04_19_17', 'BATCH_UPENNBIOMK9_04_19_17',
#        'KIT_UPENNBIOMK9_04_19_17', 'STDS_UPENNBIOMK9_04_19_17',
#        'RUNDATE_UPENNBIOMK9_04_19_17', 'ABETA_UPENNBIOMK9_04_19_17',
#        'TAU_UPENNBIOMK9_04_19_17', 'PTAU_UPENNBIOMK9_04_19_17',
#        'COMMENT_UPENNBIOMK9_04_19_17', 'update_stamp_UPENNBIOMK9_04_19_17'],
#       dtype='object', length=1907)

# %%
# select some columns
df_trunc = df[['RID', 'PTID', 'VISCODE', 'D1', 'D2', 'DXCHANGE', 
        'CDRSB', 'ADAS11', 'ADAS13', 'MMSE', 'RAVLT_immediate',
        'RAVLT_learning', 'RAVLT_forgetting', 'RAVLT_perc_forgetting',
        'FAQ', 'Ventricles', 'Hippocampus', 'WholeBrain', 'Entorhinal',
        'Fusiform', 'MidTemp', 'ICV', 'DX']]

# %%
df_trunc.head()
# Out:
#    RID        PTID VISCODE  D1  D2  DXCHANGE  CDRSB  ADAS11  ADAS13  MMSE  \
# 0    2  011_S_0002      bl   1   1       1.0    0.0   10.67   18.67  28.0
# 1    3  011_S_0003      bl   1   0       3.0    4.5   22.00   31.00  20.0
# 2    3  011_S_0003     m06   1   0       3.0    6.0   19.00   30.00  24.0
# 3    3  011_S_0003     m12   1   0       3.0    3.5   24.00   35.00  17.0
# 4    3  011_S_0003     m24   1   0       3.0    8.0   25.67   37.67  19.0
#
#    ...  RAVLT_perc_forgetting   FAQ  Ventricles  Hippocampus  WholeBrain  \
# 0  ...                54.5455   0.0    118233.0       8336.0   1229740.0
# 1  ...               100.0000  10.0     84599.0       5319.0   1129830.0
# 2  ...               100.0000  12.0     88580.0       5446.0   1100060.0
# 3  ...               100.0000  17.0     90099.0       5157.0   1095640.0
# 4  ...               100.0000  14.0     97420.0       5139.0   1088560.0
#
#    Entorhinal  Fusiform  MidTemp        ICV        DX
# 0      4177.0   16559.0  27936.0  1984660.0        NL
# 1      1791.0   15506.0  18422.0  1920690.0  Dementia
# 2      2427.0   14400.0  16972.0  1906430.0  Dementia
# 3      1596.0   14617.0  17330.0  1903820.0  Dementia
# 4      1175.0   14033.0  16398.0  1903420.0  Dementia
#
# [5 rows x 23 columns]

# %%
df_sorted = df.sort_values(by='RID')
df_sorted.head()
# Out:
#        RID        PTID VISCODE  SITE  D1  D2 COLPROT ORIGPROT    EXAMDATE  \
# 0        2  011_S_0002      bl    11   1   1   ADNI1    ADNI1  2005-09-08
# 11959    2  011_S_0002    m120    11   1   1   ADNI2    ADNI1  2015-09-22
# 11571    2  011_S_0002    m108    11   1   1   ADNI2    ADNI1  2014-10-13
# 10836    2  011_S_0002    m102    11   1   1   ADNI2    ADNI1  2014-03-17
# 5731     2  011_S_0002     m96    11   1   1   ADNI2    ADNI1  2013-09-09
#
#       DX_bl  ...  PHASE_UPENNBIOMK9_04_19_17  BATCH_UPENNBIOMK9_04_19_17  \
# 0        CN  ...
# 11959    CN  ...
# 11571    CN  ...
# 10836    CN  ...
# 5731     CN  ...
#
#       KIT_UPENNBIOMK9_04_19_17  STDS_UPENNBIOMK9_04_19_17  \
# 0
# 11959
# 11571
# 10836
# 5731
#
#       RUNDATE_UPENNBIOMK9_04_19_17 ABETA_UPENNBIOMK9_04_19_17  \
# 0
# 11959
# 11571
# 10836
# 5731
#
#       TAU_UPENNBIOMK9_04_19_17  PTAU_UPENNBIOMK9_04_19_17  \
# 0
# 11959
# 11571
# 10836
# 5731
#
#        COMMENT_UPENNBIOMK9_04_19_17  update_stamp_UPENNBIOMK9_04_19_17
# 0
# 11959
# 11571
# 10836
# 5731
#
# [5 rows x 1907 columns]

# %%
df_sorted.shape
# Out:
# (12741, 1907)

# %%
df_sorted.to_csv('data/TADPOLE_D1_D2_sorted.csv', index=False)

# %%
# Load the CSV file into a pandas DataFrame
df2 = pd.read_csv('output/prediction_test.csv')

# Define a function to determine the majority class
def get_majority_class(row):
    probs = {'CN': row['CN relative probability'], 'MCI': row['MCI relative probability'], 'AD': row['AD relative probability']}
    return max(probs, key=probs.get)

# Find unique patient IDs (PIDs)
unique_rids = df2['RID'].unique()

# List to store PIDs with the required majority shift
shift_rids = []

# Iterate through each patient
for pid in unique_rids:
    patient_data = df2[df2['RID'] == pid]
    
    # Get majority class for the first and last month
    first_month_majority = get_majority_class(patient_data[patient_data['Forecast Month'] == 1].iloc[0])
    last_month_majority = get_majority_class(patient_data[patient_data['Forecast Month'] == 84].iloc[0])
    
    # Check for the required majority shift
    if (first_month_majority == 'CN' and last_month_majority == 'MCI'):
        shift_rids.append(pid)
        
    # if (first_month_majority == 'MCI' and last_month_majority == 'AD'):
    #     shift_rids.append(pid)

# Print the result
print("Patient IDs with the required majority probability shift:")
print(shift_rids)
# Out:
# Patient IDs with the required majority probability shift:
# [125, 403, 717, 1098, 5269]

# %%
# from df_sorted, select only the rows with the required majority shift
df_shifted = df_sorted[df_sorted['RID'].isin(shift_rids)]
df_shifted.head()
# Out:
#        RID        PTID VISCODE  SITE  D1  D2 COLPROT ORIGPROT    EXAMDATE  \
# 11557  125  041_S_0125    m108    41   1   1   ADNI2    ADNI1  2015-01-22
# 6090   125  041_S_0125     m18    41   1   1   ADNI1    ADNI1  2007-08-06
# 6091   125  041_S_0125     m30    41   1   1   ADNI1    ADNI1  2008-07-25
# 6093   125  041_S_0125     m60    41   1   1   ADNI2    ADNI1  2011-05-26
# 6094   125  041_S_0125     m66    41   1   1   ADNI2    ADNI1  2011-12-02
#
#       DX_bl  ...  PHASE_UPENNBIOMK9_04_19_17  BATCH_UPENNBIOMK9_04_19_17  \
# 11557    CN  ...
# 6090     CN  ...
# 6091     CN  ...
# 6093     CN  ...
# 6094     CN  ...
#
#       KIT_UPENNBIOMK9_04_19_17  STDS_UPENNBIOMK9_04_19_17  \
# 11557
# 6090
# 6091
# 6093
# 6094
#
#       RUNDATE_UPENNBIOMK9_04_19_17 ABETA_UPENNBIOMK9_04_19_17  \
# 11557
# 6090
# 6091
# 6093
# 6094
#
#       TAU_UPENNBIOMK9_04_19_17  PTAU_UPENNBIOMK9_04_19_17  \
# 11557
# 6090
# 6091
# 6093
# 6094
#
#        COMMENT_UPENNBIOMK9_04_19_17  update_stamp_UPENNBIOMK9_04_19_17
# 11557
# 6090
# 6091
# 6093
# 6094
#
# [5 rows x 1907 columns]

# %%
df_shifted.shape
# Out:
# (59, 1907)

# %%
# for each patient, sort by VISCODE
df_shifted_sorted = df_shifted.sort_values(by=['RID', 'VISCODE'])
df_shifted_sorted.head()
# Out:
#        RID        PTID VISCODE  SITE  D1  D2 COLPROT ORIGPROT    EXAMDATE  \
# 339    125  041_S_0125      bl    41   1   1   ADNI1    ADNI1  2006-02-01
# 340    125  041_S_0125     m06    41   1   1   ADNI1    ADNI1  2006-08-07
# 11557  125  041_S_0125    m108    41   1   1   ADNI2    ADNI1  2015-01-22
# 341    125  041_S_0125     m12    41   1   1   ADNI1    ADNI1  2007-01-26
# 6090   125  041_S_0125     m18    41   1   1   ADNI1    ADNI1  2007-08-06
#
#       DX_bl  ...  PHASE_UPENNBIOMK9_04_19_17  BATCH_UPENNBIOMK9_04_19_17  \
# 339      CN  ...
# 340      CN  ...
# 11557    CN  ...
# 341      CN  ...
# 6090     CN  ...
#
#       KIT_UPENNBIOMK9_04_19_17  STDS_UPENNBIOMK9_04_19_17  \
# 339
# 340
# 11557
# 341
# 6090
#
#       RUNDATE_UPENNBIOMK9_04_19_17 ABETA_UPENNBIOMK9_04_19_17  \
# 339
# 340
# 11557
# 341
# 6090
#
#       TAU_UPENNBIOMK9_04_19_17  PTAU_UPENNBIOMK9_04_19_17  \
# 339
# 340
# 11557
# 341
# 6090
#
#        COMMENT_UPENNBIOMK9_04_19_17  update_stamp_UPENNBIOMK9_04_19_17
# 339
# 340
# 11557
# 341
# 6090
#
# [5 rows x 1907 columns]

# %%
# for RID 1098, list the RAVLT_immediate values against VISCODE
df_shifted_sorted[df_shifted_sorted['RID'] == 1098][['VISCODE', 'CDRSB', 'RAVLT_immediate']]
def sort_viscode(viscode):
    if viscode == 'bl':
        return (0, 0)  # "bl" should come first
    else:
        num = int(viscode[1:])  # Extract numeric part and convert to integer
        return (1, num)
    
df_shifted['VISCODE_SORT'] = df_shifted['VISCODE'].apply(sort_viscode)
df_shifted_sorted = df_shifted.sort_values(by=['RID', 'VISCODE_SORT'])
df_shifted_sorted.head()

#plot
import matplotlib.pyplot as plt
plt.plot(df_shifted_sorted[df_shifted_sorted['RID'] == 1098]['VISCODE'], df_shifted_sorted[df_shifted_sorted['RID'] == 1098]['RAVLT_immediate'])
plt.xlabel('VISCODE')
plt.ylabel('RAVLT_immediate')
plt.title('RAVLT_immediate values for RID 1098')
plt.show()
# Out:
# C:\Users\Osama Haque\AppData\Local\Temp\ipykernel_2756\533243598.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shifted['VISCODE_SORT'] = df_shifted['VISCODE'].apply(sort_viscode)

# %%
# for all patients, plot the RAVLT_immdiate score over time in a single plot
import matplotlib.pyplot as plt

# Find unique patient IDs (PIDs)
unique_rids = df_shifted_sorted['RID'].unique()

# Plot the RAVLT_immediate score for each patient
plt.figure(figsize=(10, 6))
for pid in unique_rids:
    patient_data = df_shifted_sorted[df_shifted_sorted['RID'] == pid]
    plt.plot(patient_data['VISCODE'], patient_data['RAVLT_immediate'], label=f'Patient {pid}')
    
    
plt.xlabel('Visit code')
plt.ylabel('RAVLT_immediate score')
plt.title('RAVLT_immediate score over time')
plt.legend()
plt.show()
